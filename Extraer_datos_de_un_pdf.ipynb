# %% [markdown]
# <a href="https://colab.research.google.com/github/h2p5b7m9/Extraer_datos_de_un_pdf/blob/main/Extraer_datos_de_un_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Convert a PDF file into a Pandas Data Frame

# %% [markdown]
# # EXTRAER DATOS DE UN PDF CON TABULA

# %%
# instalo la bilbioteca tabula-py
# %pip install tabula-py
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.9.3-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from tabula-py) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tabula-py) (1.26.4)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)
# Downloading tabula_py-2.9.3-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 22.3 MB/s eta 0:00:00
# Installing collected packages: tabula-py
# Successfully installed tabula-py-2.9.3

# %%
# convierto el PDF en una lista llamda lista_pdf
import tabula

# Lee la tabla desde un archivo PDF
lista_pdf = tabula.read_pdf("Ejemplo3_PDF.pdf", pages='all', multiple_tables=True)
# Out:
# WARNING:tabula.backend:Failed to import jpype dependencies. Fallback to subprocess.
# WARNING:tabula.backend:No module named 'jpype'

# %%
# la lista que ha creado tiene todas las hojas del PDF
# es una lista de longitud igual al numero de paginas
lista_pdf[0-2]
# Out:
#      FILAS  Col_A  Col_B  Col_C  Col_D  Col_E  Col_F  Col_G  Col_H  Col_I  \
# 0   Fila_1    336    300    330    339    322    315    350    347    334
# 1   Fila_2    322    313    343    328    301    312    309    315    336
# 2   Fila_3    349    316    303    335    328    350    350    314    332
# 3   Fila_4    319    300    306    319    326    340    339    336    337
# 4   Fila_5    305    315    321    323    336    316    346    307    317
# 5   Fila_6    341    303    310    328    317    337    320    343    333
# 6   Fila_7    343    310    314    335    341    346    310    326    342
# 7   Fila_8    306    324    315    304    336    319    336    318    349
# 8   Fila_9    348    342    345    347    304    302    349    311    305
# 9  Fila_10    340    344    347    322    346    331    340    344    310
#
#    Col_J
# 0    337
# 1    337
# 2    330
# 3    347
# 4    321
# 5    324
# 6    325
# 7    316
# 8    336
# 9    333

# %%
# ahora convierto la lista en un data frame con pandas

import pandas as pd

df1 = pd.DataFrame(lista_pdf[0])
df2 = pd.DataFrame(lista_pdf[1])
df3 = pd.DataFrame(lista_pdf[2])

# df_tabla1=pd.concat([df1, df2, df3, df4], ignore_index=True)
# print(df_tabla1.head(10))

print(df1.head())
print(df2.head())
print(df3.head())
# Out:
#    FILAS  Col1  Col2  Col3  Col4  Col5  Col6  Col7  Col8
# 0  Fila1    24    35     3    95    25    13    43    66
# 1  Fila2    80    46    64     6    75    88    69    43
# 2  Fila3    40    23    65    24    41    23    56    24
# 3  Fila4     5    71    96    13    91    52    35    45
# 4  Fila5    54    65    46    55    74    45    42    13
#     FILAS  Col_A  Col_B  Col_C  Col_D  Col_E  Col_F  Col_G  Col_H  Col_I  \
# 0  Fila_1    336    300    330    339    322    315    350    347    334
# 1  Fila_2    322    313    343    328    301    312    309    315    336
# 2  Fila_3    349    316    303    335    328    350    350    314    332
# 3  Fila_4    319    300    306    319    326    340    339    336    337
# 4  Fila_5    305    315    321    323    336    316    346    307    317
#
#    Col_J
# 0    337
# 1    337
# 2    330
# 3    347
# 4    321
#     FILAS   A   B   C   D   E   F   G   H
# 0  Fila_1  31  35  30  32  35  34  35  35
# 1  Fila_2  30  30  30  32  32  34  35  30
# 2  Fila_3  35  34  35  35  30  31  32  33
# 3  Fila_4  30  35  31  31  31  33  35  31
# 4  Fila_5  32  34  30  32  31  30  33  30
